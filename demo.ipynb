# %%
import matplotlib.pyplot as plt
import numpy as np

# 创建一个包含 x 值的数组，不包括 x = 0
x = np.linspace(0.01, 2, 400)

# 计算 y 值
y = x * np.log(x)

# 绘制图像
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Graph of y = x * ln(x)')
plt.grid(True)
plt.show()
